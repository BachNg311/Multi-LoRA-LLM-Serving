# %%
from huggingface_hub import snapshot_download

vsf_lora_path = snapshot_download(repo_id="thuanan/Llama-3.2-1B-Instruct-lora-vsf")

print(vsf_lora_path)
# Out:
# Fetching 7 files: 100%|██████████| 7/7 [00:00<?, ?it/s]
# C:\Users\nguye\.cache\huggingface\hub\models--thuanan--Llama-3.2-1B-Instruct-lora-vsf\snapshots\a4ecdb44c2d665ad5a2cfcbc6f005f3e2e3646cc

# %%
from huggingface_hub import snapshot_download

med_qa_lora_path = snapshot_download(repo_id="thuanan/med-mcqa-llama-3.2-1B-Instruct-4bit-lora")

print(med_qa_lora_path)
# Out:
# Fetching 4 files: 100%|██████████| 4/4 [00:00<?, ?it/s]
# C:\Users\nguye\.cache\huggingface\hub\models--thuanan--med-mcqa-llama-3.2-1B-Instruct-4bit-lora\snapshots\f211dff2cd67765206902672f51fb683854801e8
